# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
proj_dir = Path.cwd().parent
raw_data_dir = proj_dir/"data"/"raw"

# %%
csv_file = sorted(raw_data_dir.rglob("*.csv"))


df = pd.read_csv(csv_file[0],
                low_memory=False,
                parse_dates=["started_at","ended_at"],
                dtype={
                    "start_station_name": "string",    
                    "start_station_id": "string",         
                    "end_station_name": "string",
                    "end_station_id":"string"          
                })

df.head()
# Out:
#             ride_id  rideable_type              started_at  \
# 0  8E865410DBDE0CA9  electric_bike 2024-01-01 13:00:04.563
# 1  0403D0B3FC9CA77D  electric_bike 2024-01-08 19:36:43.520
# 2  F6DE7BB42FF550BE  electric_bike 2024-01-12 15:00:41.580
# 3  84A995BFD98030D4   classic_bike 2024-01-12 16:52:19.025
# 4  7BBEAD4F2B535813  electric_bike 2024-01-05 19:50:19.202
#
#                  ended_at           start_station_name start_station_id  \
# 0 2024-01-01 13:04:04.652                 3 St & 3 Ave          4028.03
# 1 2024-01-08 19:53:16.266  Franklin Ave & St Marks Ave          4107.05
# 2 2024-01-12 15:36:29.622           W 67 St & Broadway          7116.04
# 3 2024-01-12 17:17:29.773  Central Park West & W 68 St          7079.06
# 4 2024-01-05 20:34:42.517           W 67 St & Broadway          7116.04
#
#             end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0      Carroll St & Smith St        4225.14  40.675070 -73.987752  40.680611
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   ride_id             1000000 non-null  str
#  1   rideable_type       1000000 non-null  str
#  2   started_at          1000000 non-null  datetime64[us]
#  3   ended_at            1000000 non-null  datetime64[us]
#  4   start_station_name  999424 non-null   string
#  5   start_station_id    999424 non-null   string
#  6   end_station_name    996936 non-null   string
#  7   end_station_id      996936 non-null   string
#  8   start_lat           999424 non-null   float64
#  9   start_lng           999424 non-null   float64
#  10  end_lat             996948 non-null   float64
#  11  end_lng             996948 non-null   float64
#  12  member_casual       1000000 non-null  str
# dtypes: datetime64[us](2), float64(4), str(3), string(4)
# memory usage: 183.8 MB

# %%
df.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name     576
# start_station_id       576
# end_station_name      3064
# end_station_id        3064
# start_lat              576
# start_lng              576
# end_lat               3052
# end_lng               3052
# member_casual            0
# dtype: int64

# %%
df[df["start_station_id"].isna()].head()
# Out:
#                 ride_id  rideable_type              started_at  \
# 3687   D3E87CC64811E675  electric_bike 2024-01-13 08:49:15.112
# 15447  3E9DB8E8457C831D  electric_bike 2024-01-06 12:16:40.224
# 16000  44FEC50C562E94E1  electric_bike 2024-01-02 16:15:46.139
# 19299  78DF25A840C62EEB  electric_bike 2024-01-02 18:45:58.448
# 21094  DC097C859372FA64  electric_bike 2024-01-06 17:33:28.919
#
#                      ended_at start_station_name start_station_id  \
# 3687  2024-01-13 08:55:37.060               <NA>             <NA>
# 15447 2024-01-06 12:21:45.707               <NA>             <NA>
# 16000 2024-01-02 16:25:02.413               <NA>             <NA>
# 19299 2024-01-02 19:09:14.671               <NA>             <NA>
# 21094 2024-01-06 17:38:07.327               <NA>             <NA>
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 3687          Grand Ave & 55 St        5369.01        NaN        NaN
# ...

# %%
df.loc[df["start_station_id"].isna(), "rideable_type"].value_counts()
# Out:
# rideable_type
# electric_bike    576
# Name: count, dtype: int64

# %%
df.loc[df["end_station_id"].isna(), "rideable_type"].value_counts()
# Out:
# rideable_type
# electric_bike    2762
# classic_bike      302
# Name: count, dtype: int64

# %%
df.loc[df["start_station_id"].isna() & df["end_station_id"].isna()].shape
# Out:
# (240, 13)

# %%
df.dropna(subset=["start_station_id","end_station_id"], inplace=True)

# %%
df.loc[df["start_station_id"].isna() & df["end_station_id"].isna()].shape
# Out:
# (0, 13)

# %%
df["started_at_date"] = df["started_at"].dt.floor("h")
df["started_at_date"].head()
# Out:
# 0   2024-01-01 13:00:00
# 1   2024-01-08 19:00:00
# 2   2024-01-12 15:00:00
# 3   2024-01-12 16:00:00
# 4   2024-01-05 19:00:00
# Name: started_at_date, dtype: datetime64[us]
